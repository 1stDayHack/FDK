# %% [markdown]
# ## Hello!
# Welcome to Demo-2, the following notebook will be showing you what you can do with 1stDayKit's multifarious ML-vision tools! Specifically, we will be looking at the following 1stDayKit submodules:
# * FaceTracker (based on BlazeFace)
# * ObjectTracker (based on DaSiamRPN)
#
# Have fun!

# %% [markdown]
# ________________

# %% [markdown]
# ### 0. Importing Packages & Dependencies

# %%
#Import libs
from src.core.sot import ObjectTracker
from src.core.facetrack import FaceTracker
from src.core.utils import utils

from PIL import Image

import os
import matplotlib.pyplot as plt
import numpy

# %% [markdown]
# ### 1. Looking at Some Pretty Faces

# %%
#Initialization
face = FaceTracker(name="BlazeFace")

# %%
#Single Example
# .resize((128,128))
img1 = Image.open("misc/hyesun.png").resize((540,540))
img2 = Image.open("misc/bts.jpg")

# %%
#Cast pil to cv2
img_cv1 = utils.pil_to_cv2(img1)
img_cv2 = utils.pil_to_cv2(img2)

# %%
img_cv1.shape
# Out:
# (540, 540, 3)

# %%
#Infer and visualize
output = face.predict(img_cv1)
face.visualize(img_cv1,output)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-6-f6303e0a4a70> in <module>
#       1 #Infer and visualize
# ----> 2 output = face.predict(img_cv1)
#       3 face.visualize(img_cv1,output)
#
# ~/Documents/MachineLearning/1stdaykit/src/core/facetrack.py in predict(self, image)
#      43         """
#      44         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #Cast as right format
# ---> 45         outputs = self.predictor.predict_on_image(image)
#      46
#      47         return outputs
#
# ~/Documents/MachineLearning/1stdaykit/src/core/base_libs/BlazeFace/blazeface.py in predict_on_image(self, img)
#     179             img = torch.from_numpy(img).permute((2, 0, 1))
#     180
# --> 181         return self.predict_on_batch(img.unsqueeze(0))[0]
#     182
#     183     def predict_on_batch(self, x):
#
# ~/Documents/MachineLearning/1stdaykit/src/core/base_libs/BlazeFace/blazeface.py in predict_on_batch(self, x)
#     211         # 2. Run the neural network:
#     212         with torch.no_grad():
# --> 213             out = self.__call__(x)
#     214
#     215         # 3. Postprocess the raw predictions:
#
# ~/anaconda3/envs/1stdaykit/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/Documents/MachineLearning/1stdaykit/src/core/base_libs/BlazeFace/blazeface.py in forward(self, x)
#     120         b = x.shape[0]      # batch size, needed for reshaping later
#     121
# --> 122         x = self.backbone1(x)           # (b, 88, 16, 16)
#     123         h = self.backbone2(x)           # (b, 96, 8, 8)
#     124
#
# ~/anaconda3/envs/1stdaykit/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/anaconda3/envs/1stdaykit/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#      98     def forward(self, input):
#      99         for module in self:
# --> 100             input = module(input)
#     101         return input
#     102
#
# ~/anaconda3/envs/1stdaykit/lib/python3.8/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     548             result = self._slow_forward(*input, **kwargs)
#     549         else:
# --> 550             result = self.forward(*input, **kwargs)
#     551         for hook in self._forward_hooks.values():
#     552             hook_result = hook(self, input, result)
#
# ~/Documents/MachineLearning/1stdaykit/src/core/base_libs/BlazeFace/blazeface.py in forward(self, x)
#      40             x = F.pad(x, (0, 0, 0, 0, 0, self.channel_pad), "constant", 0)
#      41
# ---> 42         return self.act(self.convs(h) + x)
#      43
#      44
#
# RuntimeError: The size of tensor a (68) must match the size of tensor b (67) at non-singleton dimension 3

# %%
#Try multi-face image
output = face.predict(img_cv2)
face.visualize(img_cv2,output)
# Out:
# Found 1 faces
