# %% [markdown]
# ## Hello!
# Welcome to Demo-3, the following notebook will be showing you what you can do with 1stDayKit's multifarious ML-vision tools! Specifically, we will be looking at the following 1stDayKit submodules:
# * DepthEstimator (based on MiDaS)
#
# Have fun!

# %% [markdown]
# ---------------------

# %% [markdown]
# ### 0. Importing Packages & Dependencies

# %%
#Import libs
from src.core.depth import DepthEst
from src.core.utils import utils

from PIL import Image

import os
import matplotlib.pyplot as plt
import numpy

# %% [markdown]
# ### 1. Looking at Some Pretty Pictures!

# %%
#Initialization
depth = DepthEst(name="DeptEstimator")
# Out:
# Using cache found in /home/keifer/.cache/torch/hub/intel-isl_MiDaS_master
# Using cache found in /home/keifer/.cache/torch/hub/facebookresearch_WSL-Images_master
# Loading weights:  None
# Using cache found in /home/keifer/.cache/torch/hub/intel-isl_MiDaS_master

# %%
#Single Example
# .resize((128,128))
img1 = Image.open("misc/hyesun.png")
img2 = Image.open("misc/dog.jpg")

# %%
#Cast pil to cv2
img_cv1 = utils.pil_to_cv2(img1)
img_cv2 = utils.pil_to_cv2(img2)

# %%
#Infer and visualize
output = depth.predict(img_cv1) 
depth.visualize(img_cv1,output)

# %%
#Infer and visualize
output = depth.predict(img_cv2)
depth.visualize(img_cv2,output)

# %% [markdown]
# __________________________________

# %% [markdown]
# ### Thank You!
